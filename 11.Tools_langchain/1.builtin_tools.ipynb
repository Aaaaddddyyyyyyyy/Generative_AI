# %%
# !pip install langchain langchain-core langchain-community pydantic duckduckgo-search
# Out:
# Requirement already satisfied: langchain in D:\Langchain_models\venv\Lib\site-packages (1.3.14)
# Requirement already satisfied: langchain-core in D:\Langchain_models\venv\Lib\site-packages (1.5.1)
# Requirement already satisfied: langchain-community in D:\Langchain_models\venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: pydantic in D:\Langchain_models\venv\Lib\site-packages (2.13.4)
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in D:\Langchain_models\venv\Lib\site-packages (from langchain) (1.2.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in D:\Langchain_models\venv\Lib\site-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\Langchain_models\venv\Lib\site-packages (from langchain-core) (0.10.5)
# Requirement already satisfied: packaging>=23.2.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-core) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Langchain_models\venv\Lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in D:\Langchain_models\venv\Lib\site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\Langchain_models\venv\Lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in D:\Langchain_models\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in D:\Langchain_models\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in D:\Langchain_models\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in D:\Langchain_models\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in D:\Langchain_models\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in D:\Langchain_models\venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in D:\Langchain_models\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in D:\Langchain_models\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in D:\Langchain_models\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in D:\Langchain_models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in D:\Langchain_models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\Langchain_models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\Langchain_models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in D:\Langchain_models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in D:\Langchain_models\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: certifi in D:\Langchain_models\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in D:\Langchain_models\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in D:\Langchain_models\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in D:\Langchain_models\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in D:\Langchain_models\venv\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in D:\Langchain_models\venv\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in D:\Langchain_models\venv\Lib\site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in D:\Langchain_models\venv\Lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in D:\Langchain_models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in D:\Langchain_models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in D:\Langchain_models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in D:\Langchain_models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in D:\Langchain_models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in D:\Langchain_models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in D:\Langchain_models\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in D:\Langchain_models\venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in D:\Langchain_models\venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Langchain_models\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\Langchain_models\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Requirement already satisfied: greenlet>=1 in D:\Langchain_models\venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.4)
# Requirement already satisfied: click>=8.1.8 in D:\Langchain_models\venv\Lib\site-packages (from duckduckgo-search) (8.4.2)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-1.3.1-cp310-abi3-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: lxml>=5.3.0 in D:\Langchain_models\venv\Lib\site-packages (from duckduckgo-search) (6.1.1)
# Requirement already satisfied: colorama in D:\Langchain_models\venv\Lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading primp-1.3.1-cp310-abi3-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.8/4.7 MB 7.3 MB/s eta 0:00:01
#    ------------------------------- -------- 3.7/4.7 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 13.1 MB/s  0:00:00
# Installing collected packages: primp, duckduckgo-search
#
#    -------------------- ------------------- 1/2 [duckduckgo-search]
#    ---------------------------------------- 2/2 [duckduckgo-search]
#
# Successfully installed duckduckgo-search-8.1.1 primp-1.3.1

# %%
# !pip install -U ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.14.4-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: click>=8.1.8 in D:\Langchain_models\venv\Lib\site-packages (from ddgs) (8.4.2)
# Requirement already satisfied: primp>=1.2.3 in D:\Langchain_models\venv\Lib\site-packages (from ddgs) (1.3.1)
# Requirement already satisfied: lxml>=4.9.4 in D:\Langchain_models\venv\Lib\site-packages (from ddgs) (6.1.1)
# Requirement already satisfied: httpx>=0.28.1 in D:\Langchain_models\venv\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in D:\Langchain_models\venv\Lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Requirement already satisfied: anyio in D:\Langchain_models\venv\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.14.2)
# Requirement already satisfied: certifi in D:\Langchain_models\venv\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in D:\Langchain_models\venv\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in D:\Langchain_models\venv\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.18)
# Requirement already satisfied: h11>=0.16 in D:\Langchain_models\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Collecting brotli (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading brotli-1.2.0-cp314-cp314-win_amd64.whl.metadata (6.3 kB)
# Collecting h2<5,>=3 (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading h2-4.4.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.2 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hpack-4.2.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading ddgs-9.14.4-py3-none-any.whl (70 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Downloading h2-4.4.0-py3-none-any.whl (62 kB)
# Downloading hpack-4.2.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Downloading brotli-1.2.0-cp314-cp314-win_amd64.whl (375 kB)
# Installing collected packages: brotli, socksio, hyperframe, hpack, fake-useragent, h2, ddgs
#
#    ----- ---------------------------------- 1/7 [socksio]
#    ----------------- ---------------------- 3/7 [hpack]
#    ---------------------- ----------------- 4/7 [fake-useragent]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------------- 7/7 [ddgs]
#
# Successfully installed brotli-1.2.0 ddgs-9.14.4 fake-useragent-2.2.0 h2-4.4.0 hpack-4.2.0 hyperframe-6.1.0 socksio-1.0.0

# %% [markdown]
# Builtin tools

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool= DuckDuckGoSearchRun()
results=search_tool.invoke('top news in india todday')
print(results)
# Out:
# Get the latest breaking news from India covering politics, economy, social issues, technology, sports, and more. Stay updated with in-depth analysis and top headlines from across the country. Latest News Today: Follow today's news updates and recent stories from India and across the globe, covering politics, business, technology, and sports. The latest news headlines on Life Style, Business, Politics, Hollywood and News from across the world at The Times of India. Get the latest news and breaking news today from India and around the world. Zee News covers politics, business, technology, entertainment, sports, cricket, festivals, and current affairs with live updates and in-depth reports. Stay informed with the latest news today. Get breaking news, live updates, and top headlines from India and around the world on News24

# %% [markdown]
# Builtin - Shell tool

# %%
from langchain_community.tools import ShellTool
shell_tool= ShellTool()
results=shell_tool.invoke('whoami')
print(results)
# Out:
# Executing command:
#  whoami
# spartan\aditya
# d:\Langchain_models\venv\Lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
