# %%
import os
api_key="GROQ_API_KEY"

# %%
# !pip install -q langchain-groq langchain-community langchain-core requests duckduckgo-search

# %%
from langchain_groq import ChatGroq
from langchain_core.tools import tool
import requests

# %%
from  langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
result= search_tool.invoke('top 5 news of rohit sharma')
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_10060\4202550358.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from  langchain_community.tools import DuckDuckGoSearchRun

# %%
result
# Out:
# "Read about Rohit Sharma cricket player from India profile, stats, rankings, records, videos, photos at Cricinfo. Top News. The Indian Express. From a slow start to an all-time great. Rohit Sharma scored just 5 ODI hundreds in his first 126 matches. However, in what has been a remarkable turnaround, he has smashed 29 more in his next 162 ODIs. Rohit Sharma International Career Ends At Lord's ODI | Dial News. How did Rohit Sharma respond to the rumors about his international future? Rohit Sharma shrugged off the speculation, stating his sole commitment is contributing on the field and that public commentary does not affect his focus. Amidst these rumors, he scored 138 against England. Rohit Sharma Centuries List: Rohit Sharma has scored more than 17,000 runs with the help of 47 centuries in International cricket."

# %%
llm= ChatGroq(model="llama-3.3-70b-versatile")

# %%
llm.invoke('hi')
# Out:
# AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 36, 'total_tokens': 59, 'completion_time': 0.043682504, 'completion_tokens_details': None, 'prompt_time': 0.000924033, 'prompt_tokens_details': None, 'queue_time': 0.052614197, 'total_time': 0.044606537}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fab59-3b18-7fb1-be09-038f22864808-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 23, 'total_tokens': 59})

# %% [markdown]
# Agent Building

# %%
from langchain.agents import create_agent

# %%
# step 2 create a react agent manually
agent= create_agent(
    model=llm,
    tools=[search_tool],
    system_prompt="you are a helpful agent"
)

# %%
# step 3 - invoke
response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Who is the Prime Minister of India?"
            }
        ]
    }
)

print(response["messages"][-1].content)
# Out:
# The current Prime Minister of India is Narendra Modi.

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 response['output']
#
# KeyError: 'output'
