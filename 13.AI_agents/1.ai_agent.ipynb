# %%
import os
api_key="GROQ_API_KEY"

# %%
# !pip install -q langchain-groq langchain-community langchain-core requests duckduckgo-search

# %%
from langchain_groq import ChatGroq
from langchain_core.tools import tool
import requests

# %%
from  langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
result= search_tool.invoke('top 5 news of rohit sharma')

# %%
result
# Out:
# '3 weeks ago - Dec 13, ANI / Updated:; 2021; Ist, 11:56. "On this day in 2017: Rohit Sharma blasted his 3rd double ton in ODIs | Cricket News - Times of India". The Times of India (अंग्रेज़ी भाषा में). अभिगमन तिथि: 2022-04-06. 1 week ago - Rohit Sharma 5000 runs in away ODI: रोहित शर्मा ने इंग्लैंड के खिलाफ कार्डिफ वनडे में नया इतिहास रच दिया है. 3 weeks ago - ... Rohit Sharma Hit The Nets In England: भारत के दिग्गज बल्लेबाज और पूर्व कप्तान रोहित शर्मा का एक वीडियो सोशल मीडिया ... 1 week ago - Sharma played the first three seasons of IPL for Deccan Chargers and in the players\' auction for IPL 4, he was sold for $2m to Mumbai Indians. ... Rohit Sharma is back for India\'s ODI series against England, sparking debate about his 2027 World ... 2 weeks ago - Former BCCI chief selector Krishnamachari Srikkanth has opened up about the "unfortunate" decision to exclude Rohit Sharma from India\'s 2011 World Cup squad.'

# %%
llm= ChatGroq(model="llama-3.3-70b-versatile")
